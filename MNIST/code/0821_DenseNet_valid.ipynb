# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense
from tensorflow.keras.layers import concatenate, Dropout, GlobalAveragePooling2D
from tensorflow.keras.layers import BatchNormalization, Activation, AveragePooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# seed
import os
seed = 123
os.environ['PYTHONHASHSEED'] = str(seed)
np.random.seed(seed)
tf.set_random_seed(seed)

# %%
train = np.load('data/train.npy', allow_pickle = 'True')
test = np.load('data/test.npy', allow_pickle = 'True')

# %%
x = train[:,2:]
x = np.reshape(x, (-1, 28, 28, 1))

x_letter = train[:,1]
x_letter = np.reshape(x_letter, (-1, 1))
en = OneHotEncoder()
x_letter = en.fit_transform(x_letter).toarray()

y = train[:,0]
y = np.reshape(y, (-1, 1))
en = OneHotEncoder()
y = en.fit_transform(y).toarray()

print(x.shape)
print(x_letter.shape)
print(y.shape)
# Out:
# (2048, 28, 28, 1)
# (2048, 26)
# (2048, 10)

# %%
valid_size = 48
valid_x = x[-valid_size:]
x = x[:-48]

valid_x_letter = x_letter[-valid_size:]
x_letter = x_letter[:-48]

valid_y = y[-valid_size:]
y = y[:-48]

print(x.shape)
print(valid_x.shape)
print(x_letter.shape)
print(valid_x_letter.shape)
print(y.shape)
print(valid_y.shape)
# Out:
# (2000, 28, 28, 1)
# (48, 28, 28, 1)
# (2000, 26)
# (48, 26)
# (2000, 10)
# (48, 10)

# %%
image_generator = ImageDataGenerator(width_shift_range=0.1,
                                     height_shift_range=0.1, 
                                     zoom_range=[0.8,1.2],
                                     shear_range=10)

# %%
x_total = x.copy()
def augment(x):
    aug_list = []
    for i in range(x.shape[0]):
        num_aug = 0
        tmp = x[i]
        tmp = tmp.reshape((1,) + tmp.shape)
        for x_aug in image_generator.flow(tmp, batch_size = 1) :
            if num_aug >= 1:
                break
            aug_list.append(x_aug[0])
            num_aug += 1
    aug_list = np.array(aug_list)
    return aug_list

n = 2
for i in range(n):
    arr = augment(x)
    x_total = np.concatenate((x_total, arr), axis=0)
    if i > n:
        break

print(x_total.shape)
# Out:
# (6000, 28, 28, 1)

# %%
y_total = y.copy()
for i in range(n):
    arr = y.copy()
    y_total = np.concatenate((y_total, arr), axis=0)

print(y_total.shape)
# Out:
# (6000, 10)

# %%
x_letter_total = x_letter.copy()
for i in range(n):
    arr = x_letter.copy()
    x_letter_total = np.concatenate((x_letter_total, arr), axis=0)
    
print(x_letter_total.shape)
# Out:
# (6000, 26)

# %%
x_train, x_val, y_train, y_val = train_test_split(x_total, y_total, test_size=0.2, shuffle=True)#, stratify=y_total)
x_letter_train = x_letter_total[:x_train.shape[0],:]
x_letter_val = x_letter_total[x_train.shape[0]:,:]

print(x_train.shape)
print(x_val.shape)
print(y_train.shape)
print(y_val.shape)
print(x_letter_train.shape)
print(x_letter_val.shape)
# Out:
# (4800, 28, 28, 1)
# (1200, 28, 28, 1)
# (4800, 10)
# (1200, 10)
# (4800, 26)
# (1200, 26)

# %%
def Conv_block(x, growth_rate, activation='relu'):
    x_l = BatchNormalization()(x)
    x_l = Activation(activation)(x_l)
    x_l = Conv2D(growth_rate*4, (1,1), padding='same', kernel_initializer='he_normal')(x_l)
    
    x_l = BatchNormalization()(x_l)
    x_l = Activation(activation)(x_l)
    x_l = Conv2D(growth_rate, (3,3), padding='same', kernel_initializer='he_normal')(x_l)
    
    x = concatenate([x, x_l])
    return x

def Dense_block(x, layers, growth_rate=32):
    for i in range(layers):
        x = Conv_block(x, growth_rate)
    return x

def Transition_layer(x, compression_factor=0.5, activation='relu'):
    reduced_filters = int(tf.keras.backend.int_shape(x)[-1] * compression_factor)
    
    x = BatchNormalization()(x)
    x = Activation(activation)(x)
    x = Conv2D(reduced_filters, (1,1), padding='same', kernel_initializer='he_normal')(x)
    
    x = AveragePooling2D((2,2), padding='same', strides=2)(x)
    return x

def DenseNet(model_input, classes, densenet_type='DenseNet-121'):
    x = Conv2D(base_growth_rate*2, (5,5), padding='same', strides=1,
               kernel_initializer='he_normal')(model_input)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    
    x = MaxPooling2D((2,2), padding='same', strides=1)(x)
    
    x = Dense_block(x, layers_in_block[densenet_type][0], base_growth_rate)
    x = Transition_layer(x, compression_factor=0.5)
    x = Dense_block(x, layers_in_block[densenet_type][1], base_growth_rate)
    x = Transition_layer(x, compression_factor=0.5)
    x = Dense_block(x, layers_in_block[densenet_type][2], base_growth_rate)
    #x = Transition_layer(x, compression_factor=0.5)
    #x = Dense_block(x, layers_in_block[densenet_type][3], base_growth_rate)
    
    x = GlobalAveragePooling2D()(x)
    
    model_output = Dense(classes, activation='softmax', kernel_initializer='he_normal')(x)
    
    model = Model(model_input, model_output, name=densenet_type)
    
    return model

# %%
layers_in_block = {'DenseNet-121':[6, 12, 24, 16],
                   'DenseNet-169':[6, 12, 32, 32],
                   'DenseNet-201':[6, 12, 48, 32],
                   'DenseNet-265':[6, 12, 64, 48],
                   'myDenseNet':[8, 12, 16, 32]}

base_growth_rate = 32

model_input = Input(shape=(28,28,1))
classes = 10

model = DenseNet(model_input, classes, 'DenseNet-121')

model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            (None, 28, 28, 1)    0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 28, 28, 64)   1664        input_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 28, 28, 64)   256         conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 28, 28, 64)   0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 28, 28, 64)   0           activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 28, 28, 64)   256         max_pooling2d[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 28, 28, 64)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 28, 28, 128)  8320        activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 28, 28, 128)  512         conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 28, 28, 128)  0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 28, 28, 32)   36896       activation_2[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 28, 28, 96)   0           max_pooling2d[0][0]
#                                                                  conv2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 28, 28, 96)   384         concatenate[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 28, 28, 96)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 28, 28, 128)  12416       activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 28, 28, 128)  512         conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 28, 28, 128)  0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 28, 28, 32)   36896       activation_4[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 28, 28, 128)  0           concatenate[0][0]
#                                                                  conv2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 28, 28, 128)  512         concatenate_1[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 28, 28, 128)  0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 28, 28, 128)  16512       activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 28, 28, 128)  512         conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 28, 28, 128)  0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 28, 28, 32)   36896       activation_6[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 28, 28, 160)  0           concatenate_1[0][0]
#                                                                  conv2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 28, 28, 160)  640         concatenate_2[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 28, 28, 160)  0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 28, 28, 128)  20608       activation_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 28, 28, 128)  512         conv2d_8[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 28, 28, 128)  0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 28, 28, 32)   36896       activation_8[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 28, 28, 192)  0           concatenate_2[0][0]
#                                                                  conv2d_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 28, 28, 192)  768         concatenate_3[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 28, 28, 192)  0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 28, 28, 128)  24704       activation_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 28, 28, 128)  512         conv2d_10[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 28, 28, 128)  0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 28, 28, 32)   36896       activation_10[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 28, 28, 224)  0           concatenate_3[0][0]
#                                                                  conv2d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 28, 28, 224)  896         concatenate_4[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 28, 28, 224)  0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 28, 28, 128)  28800       activation_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 28, 28, 128)  512         conv2d_12[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 28, 28, 128)  0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 28, 28, 32)   36896       activation_12[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 28, 28, 256)  0           concatenate_4[0][0]
#                                                                  conv2d_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 28, 28, 256)  1024        concatenate_5[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 28, 28, 256)  0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 28, 28, 128)  32896       activation_13[0][0]
# __________________________________________________________________________________________________
# average_pooling2d (AveragePooli (None, 14, 14, 128)  0           conv2d_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 14, 14, 128)  512         average_pooling2d[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 14, 14, 128)  0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 14, 14, 128)  16512       activation_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 14, 14, 128)  512         conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 14, 14, 128)  0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 14, 14, 32)   36896       activation_15[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 14, 14, 160)  0           average_pooling2d[0][0]
#                                                                  conv2d_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 14, 14, 160)  640         concatenate_6[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 14, 14, 160)  0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 14, 14, 128)  20608       activation_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 14, 14, 128)  512         conv2d_17[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 14, 14, 128)  0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 14, 14, 32)   36896       activation_17[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 14, 14, 192)  0           concatenate_6[0][0]
#                                                                  conv2d_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 14, 14, 192)  768         concatenate_7[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 14, 14, 192)  0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 14, 14, 128)  24704       activation_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 14, 14, 128)  512         conv2d_19[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 14, 14, 128)  0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 14, 14, 32)   36896       activation_19[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 14, 14, 224)  0           concatenate_7[0][0]
#                                                                  conv2d_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 14, 14, 224)  896         concatenate_8[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 14, 14, 224)  0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 14, 14, 128)  28800       activation_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 14, 14, 128)  512         conv2d_21[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 14, 14, 128)  0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 14, 14, 32)   36896       activation_21[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 14, 14, 256)  0           concatenate_8[0][0]
#                                                                  conv2d_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 14, 14, 256)  1024        concatenate_9[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 14, 14, 256)  0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 14, 14, 128)  32896       activation_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 14, 14, 128)  512         conv2d_23[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 14, 14, 128)  0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 14, 14, 32)   36896       activation_23[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 14, 14, 288)  0           concatenate_9[0][0]
#                                                                  conv2d_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 14, 14, 288)  1152        concatenate_10[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 14, 14, 288)  0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 14, 14, 128)  36992       activation_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 14, 14, 128)  512         conv2d_25[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 14, 14, 128)  0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 14, 14, 32)   36896       activation_25[0][0]
# __________________________________________________________________________________________________
# concatenate_11 (Concatenate)    (None, 14, 14, 320)  0           concatenate_10[0][0]
#                                                                  conv2d_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 14, 14, 320)  1280        concatenate_11[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 14, 14,
0][0]
#                                                                  conv2d_75[0][0]
# __________________________________________________________________________________________________
# batch_normalization_75 (BatchNo (None, 7, 7, 832)    3328        concatenate_35[0][0]
# __________________________________________________________________________________________________
# activation_75 (Activation)      (None, 7, 7, 832)    0           batch_normalization_75[0][0]
# __________________________________________________________________________________________________
# conv2d_76 (Conv2D)              (None, 7, 7, 128)    106624      activation_75[0][0]
# __________________________________________________________________________________________________
# batch_normalization_76 (BatchNo (None, 7, 7, 128)    512         conv2d_76[0][0]
# __________________________________________________________________________________________________
# activation_76 (Activation)      (None, 7, 7, 128)    0           batch_normalization_76[0][0]
# __________________________________________________________________________________________________
# conv2d_77 (Conv2D)              (None, 7, 7, 32)     36896       activation_76[0][0]
# __________________________________________________________________________________________________
# concatenate_36 (Concatenate)    (None, 7, 7, 864)    0           concatenate_35[0][0]
#                                                                  conv2d_77[0][0]
# __________________________________________________________________________________________________
# batch_normalization_77 (BatchNo (None, 7, 7, 864)    3456        concatenate_36[0][0]
# __________________________________________________________________________________________________
# activation_77 (Activation)      (None, 7, 7, 864)    0           batch_normalization_77[0][0]
# __________________________________________________________________________________________________
# conv2d_78 (Conv2D)              (None, 7, 7, 128)    110720      activation_77[0][0]
# __________________________________________________________________________________________________
# batch_normalization_78 (BatchNo (None, 7, 7, 128)    512         conv2d_78[0][0]
# __________________________________________________________________________________________________
# activation_78 (Activation)      (None, 7, 7, 128)    0           batch_normalization_78[0][0]
# __________________________________________________________________________________________________
# conv2d_79 (Conv2D)              (None, 7, 7, 32)     36896       activation_78[0][0]
# __________________________________________________________________________________________________
# concatenate_37 (Concatenate)    (None, 7, 7, 896)    0           concatenate_36[0][0]
#                                                                  conv2d_79[0][0]
# __________________________________________________________________________________________________
# batch_normalization_79 (BatchNo (None, 7, 7, 896)    3584        concatenate_37[0][0]
# __________________________________________________________________________________________________
# activation_79 (Activation)      (None, 7, 7, 896)    0           batch_normalization_79[0][0]
# __________________________________________________________________________________________________
# conv2d_80 (Conv2D)              (None, 7, 7, 128)    114816      activation_79[0][0]
# __________________________________________________________________________________________________
# batch_normalization_80 (BatchNo (None, 7, 7, 128)    512         conv2d_80[0][0]
# __________________________________________________________________________________________________
# activation_80 (Activation)      (None, 7, 7, 128)    0           batch_normalization_80[0][0]
# __________________________________________________________________________________________________
# conv2d_81 (Conv2D)              (None, 7, 7, 32)     36896       activation_80[0][0]
# __________________________________________________________________________________________________
# concatenate_38 (Concatenate)    (None, 7, 7, 928)    0           concatenate_37[0][0]
#                                                                  conv2d_81[0][0]
# __________________________________________________________________________________________________
# batch_normalization_81 (BatchNo (None, 7, 7, 928)    3712        concatenate_38[0][0]
# __________________________________________________________________________________________________
# activation_81 (Activation)      (None, 7, 7, 928)    0           batch_normalization_81[0][0]
# __________________________________________________________________________________________________
# conv2d_82 (Conv2D)              (None, 7, 7, 128)    118912      activation_81[0][0]
# __________________________________________________________________________________________________
# batch_normalization_82 (BatchNo (None, 7, 7, 128)    512         conv2d_82[0][0]
# __________________________________________________________________________________________________
# activation_82 (Activation)      (None, 7, 7, 128)    0           batch_normalization_82[0][0]
# __________________________________________________________________________________________________
# conv2d_83 (Conv2D)              (None, 7, 7, 32)     36896       activation_82[0][0]
# __________________________________________________________________________________________________
# concatenate_39 (Concatenate)    (None, 7, 7, 960)    0           concatenate_38[0][0]
#                                                                  conv2d_83[0][0]
# __________________________________________________________________________________________________
# batch_normalization_83 (BatchNo (None, 7, 7, 960)    3840        concatenate_39[0][0]
# __________________________________________________________________________________________________
# activation_83 (Activation)      (None, 7, 7, 960)    0           batch_normalization_83[0][0]
# __________________________________________________________________________________________________
# conv2d_84 (Conv2D)              (None, 7, 7, 128)    123008      activation_83[0][0]
# __________________________________________________________________________________________________
# batch_normalization_84 (BatchNo (None, 7, 7, 128)    512         conv2d_84[0][0]
# __________________________________________________________________________________________________
# activation_84 (Activation)      (None, 7, 7, 128)    0           batch_normalization_84[0][0]
# __________________________________________________________________________________________________
# conv2d_85 (Conv2D)              (None, 7, 7, 32)     36896       activation_84[0][0]
# __________________________________________________________________________________________________
# concatenate_40 (Concatenate)    (None, 7, 7, 992)    0           concatenate_39[0][0]
#                                                                  conv2d_85[0][0]
# __________________________________________________________________________________________________
# batch_normalization_85 (BatchNo (None, 7, 7, 992)    3968        concatenate_40[0][0]
# __________________________________________________________________________________________________
# activation_85 (Activation)      (None, 7, 7, 992)    0           batch_normalization_85[0][0]
# __________________________________________________________________________________________________
# conv2d_86 (Conv2D)              (None, 7, 7, 128)    127104      activation_85[0][0]
# __________________________________________________________________________________________________
# batch_normalization_86 (BatchNo (None, 7, 7, 128)    512         conv2d_86[0][0]
# __________________________________________________________________________________________________
# activation_86 (Activation)      (None, 7, 7, 128)    0           batch_normalization_86[0][0]
# __________________________________________________________________________________________________
# conv2d_87 (Conv2D)              (None, 7, 7, 32)     36896       activation_86[0][0]
# __________________________________________________________________________________________________
# concatenate_41 (Concatenate)    (None, 7, 7, 1024)   0           concatenate_40[0][0]
#                                                                  conv2d_87[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 1024)         0           concatenate_41[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 10)           10250       global_average_pooling2d[0][0]
# ==================================================================================================
# Total params: 4,328,394
# Trainable params: 4,277,002
# Non-trainable params: 51,392
# __________________________________________________________________________________________________

# %%
model.compile(optimizer = 'adam', metrics = ['accuracy'], loss = 'categorical_crossentropy')

#es = EarlyStopping(monitor='val_loss', patience=20, mode='min', verbose=1)
cp = ModelCheckpoint('./models/{epoch:02d}-{val_acc:.4f}.h5', monitor='val_loss',
                     save_best_only=True, mode='min')

history = model.fit(x_train, y_train,
                    validation_data=(x_val, y_val), 
                    batch_size=64, epochs=100, verbose=1, callbacks = [cp])
# Out:
# Train on 4800 samples, validate on 1200 samples
# Epoch 1/100
# 4800/4800 [==============================] - 60s 12ms/step - loss: 2.2770 - acc: 0.2527 - val_loss: 13.1096 - val_acc: 0.1167
# Epoch 2/100
# 4800/4800 [==============================] - 28s 6ms/step - loss: 1.3219 - acc: 0.5367 - val_loss: 4.0300 - val_acc: 0.2850
# Epoch 3/100
# 4800/4800 [==============================] - 28s 6ms/step - loss: 0.9276 - acc: 0.6867 - val_loss: 3.9975 - val_acc: 0.3542
# Epoch 4/100
# 4800/4800 [==============================] - 28s 6ms/step - loss: 0.7268 - acc: 0.7492 - val_loss: 2.0269 - val_acc: 0.4825
# Epoch 5/100
# 4800/4800 [==============================] - 28s 6ms/step - loss: 0.5556 - acc: 0.8106 - val_loss: 2.6357 - val_acc: 0.4842
# Epoch 6/100
# 4800/4800 [==============================] - 28s 6ms/step - loss: 0.4408 - acc: 0.8517 - val_loss: 1.1195 - val_acc: 0.6833
# Epoch 7/100
# 4800/4800 [==============================] - 28s 6ms/step - loss: 0.3385 - acc: 0.8850 - val_loss: 0.7109 - val_acc: 0.7775
# Epoch 8/100
# 4800/4800 [==============================] - 28s 6ms/step - loss: 0.3272 - acc: 0.8873 - val_loss: 0.8869 - val_acc: 0.7558
# Epoch 9/100
# 4800/4800 [==============================] - 28s 6ms/step - loss: 0.2412 - acc: 0.9125 - val_loss: 2.0926 - val_acc: 0.5792
# Epoch 10/100
# 4800/4800 [==============================] - 28s 6ms/step - loss: 0.2624 - acc: 0.9115 - val_loss: 0.9547 - val_acc: 0.7600
# Epoch 11/100
# 4800/4800 [==============================] - 28s 6ms/step - loss: 0.1967 - acc: 0.9285 - val_loss: 1.1770 - val_acc: 0.7325
# Epoch 12/100
# 4800/4800 [==============================] - 28s 6ms/step - loss: 0.2282 - acc: 0.9225 - val_loss: 1.0886 - val_acc: 0.7650
# Epoch 13/100
# 4800/4800 [==============================] - 28s 6ms/step - loss: 0.1427 - acc: 0.9515 - val_loss: 0.4618 - val_acc: 0.8642
# Epoch 14/100
# 4800/4800 [==============================] - 28s 6ms/step - loss: 0.1512 - acc: 0.9494 - val_loss: 0.5353 - val_acc: 0.8450
# Epoch 15/100
# 4800/4800 [==============================] - 28s 6ms/step - loss: 0.0833 - acc: 0.9723 - val_loss: 0.8446 - val_acc: 0.8008
# Epoch 16/100
# 4800/4800 [==============================] - 28s 6ms/step - loss: 0.0596 - acc: 0.9800 - val_loss: 0.7150 - val_acc: 0.8208
# Epoch 17/100
# 4800/4800 [==============================] - 28s 6ms/step - loss: 0.0741 - acc: 0.9777 - val_loss: 1.1014 - val_acc: 0.7550
# Epoch 18/100
# 4800/4800 [==============================] - 28s 6ms/step - loss: 0.2190 - acc: 0.9323 - val_loss: 2.5653 - val_acc: 0.6308
# Epoch 19/100
# 4800/4800 [==============================] - 28s 6ms/step - loss: 0.1331 - acc: 0.9542 - val_loss: 0.5077 - val_acc: 0.8683
# Epoch 20/100
# 4800/4800 [==============================] - 28s 6ms/step - loss: 0.0440 - acc: 0.9848 - val_loss: 0.5176 - val_acc: 0.8633
# Epoch 21/100
# 4800/4800 [==============================] - 28s 6ms/step - loss: 0.0642 - acc: 0.9788 - val_loss: 0.5314 - val_acc: 0.8800
# Epoch 22/100
# 4800/4800 [==============================] - 28s 6ms/step - loss: 0.0511 - acc: 0.9825 - val_loss: 0.5979 - val_acc: 0.8600
# Epoch 23/100
# 4800/4800 [==============================] - 28s 6ms/step - loss: 0.0837 - acc: 0.9725 - val_loss: 0.7224 - val_acc: 0.8242
# Epoch 24/100
# 4800/4800 [==============================] - 28s 6ms/step - loss: 0.1437 - acc: 0.9531 - val_loss: 1.0624 - val_acc: 0.7900
# Epoch 25/100
# 4800/4800 [==============================] - 28s 6ms/step - loss: 0.1357 - acc: 0.9565 - val_loss: 1.0175 - val_acc: 0.8025
# Epoch 26/100
# 4800/4800 [==============================] - 28s 6ms/step - loss: 0.1273 - acc: 0.9604 - val_loss: 0.6975 - val_acc: 0.8433
# Epoch 27/100
# 4800/4800 [==============================] - 28s 6ms/step - loss: 0.0460 - acc: 0.9848 - val_loss: 0.5955 - val_acc: 0.8600
# Epoch 28/100
# 4800/4800 [==============================] - 28s 6ms/step - loss: 0.0517 - acc: 0.9827 - val_loss: 0.6094 - val_acc: 0.8542
# Epoch 29/100
# 4800/4800 [==============================] - 28s 6ms/step - loss: 0.0428 - acc: 0.9850 - val_loss: 0.5418 - val_acc: 0.8667
# Epoch 30/100
# 4800/4800 [==============================] - 28s 6ms/step - loss: 0.0746 - acc: 0.9756 - val_loss: 0.6921 - val_acc: 0.8342
# Epoch 31/100
# 4800/4800 [==============================] - 28s 6ms/step - loss: 0.0305 - acc: 0.9898 - val_loss: 0.8329 - val_acc: 0.8375
# Epoch 32/100
# 4800/4800 [==============================] - 28s 6ms/step - loss: 0.0255 - acc: 0.9908 - val_loss: 0.3985 - val_acc: 0.9075
# Epoch 33/100
# 4800/4800 [==============================] - 28s 6ms/step - loss: 0.0541 - acc: 0.9825 - val_loss: 1.5684 - val_acc: 0.7433
# Epoch 34/100
# 4800/4800 [==============================] - 28s 6ms/step - loss: 0.0779 - acc: 0.9729 - val_loss: 0.7116 - val_acc: 0.8542
# Epoch 35/100
# 4800/4800 [==============================] - 28s 6ms/step - loss: 0.0460 - acc: 0.9854 - val_loss: 2.4308 - val_acc: 0.6642
# Epoch 36/100
# 4800/4800 [==============================] - 28s 6ms/step - loss: 0.0661 - acc: 0.9794 - val_loss: 0.5627 - val_acc: 0.8675
# Epoch 37/100
# 4800/4800 [==============================] - 28s 6ms/step - loss: 0.0421 - acc: 0.9856 - val_loss: 0.6612 - val_acc: 0.8583
# Epoch 38/100
# 4800/4800 [==============================] - 28s 6ms/step - loss: 0.0375 - acc: 0.9883 - val_loss: 1.7382 - val_acc: 0.7108
# Epoch 39/100
# 4800/4800 [==============================] - 28s 6ms/step - loss: 0.0837 - acc: 0.9717 - val_loss: 0.9045 - val_acc: 0.8183
# Epoch 40/100
# 4800/4800 [==============================] - 28s 6ms/step - loss: 0.0571 - acc: 0.9823 - val_loss: 2.4597 - val_acc: 0.6658
# Epoch 41/100
# 4800/4800 [==============================] - 28s 6ms/step - loss: 0.1055 - acc: 0.9731 - val_loss: 1.1698 - val_acc: 0.8100
# Epoch 42/100
# 4800/4800 [==============================] - 28s 6ms/step - loss: 0.0499 - acc: 0.9833 - val_loss: 0.4504 - val_acc: 0.8908
# Epoch 43/100
# 4800/4800 [==============================] - 28s 6ms/step - loss: 0.0311 - acc: 0.9898 - val_loss: 0.6203 - val_acc: 0.8650
# Epoch 44/100
# 4800/4800 [==============================] - 28s 6ms/step - loss: 0.
100
# 4800/4800 [==============================] - 28s 6ms/step - loss: 5.4583e-05 - acc: 1.0000 - val_loss: 0.1286 - val_acc: 0.9650
# Epoch 76/100
# 4800/4800 [==============================] - 28s 6ms/step - loss: 6.5360e-05 - acc: 1.0000 - val_loss: 0.1333 - val_acc: 0.9633
# Epoch 77/100
# 4800/4800 [==============================] - 28s 6ms/step - loss: 5.6632e-05 - acc: 1.0000 - val_loss: 0.1292 - val_acc: 0.9625
# Epoch 78/100
# 4800/4800 [==============================] - 28s 6ms/step - loss: 2.8984e-05 - acc: 1.0000 - val_loss: 0.1276 - val_acc: 0.9633
# Epoch 79/100
# 4800/4800 [==============================] - 28s 6ms/step - loss: 3.5366e-05 - acc: 1.0000 - val_loss: 0.1263 - val_acc: 0.9625
# Epoch 80/100
# 4800/4800 [==============================] - 28s 6ms/step - loss: 4.0570e-05 - acc: 1.0000 - val_loss: 0.1255 - val_acc: 0.9625
# Epoch 81/100
# 4800/4800 [==============================] - 28s 6ms/step - loss: 5.1477e-05 - acc: 1.0000 - val_loss: 0.1280 - val_acc: 0.9617
# Epoch 82/100
# 4800/4800 [==============================] - 28s 6ms/step - loss: 2.4615e-05 - acc: 1.0000 - val_loss: 0.1275 - val_acc: 0.9617
# Epoch 83/100
# 4800/4800 [==============================] - 28s 6ms/step - loss: 4.9699e-05 - acc: 1.0000 - val_loss: 0.1236 - val_acc: 0.9642
# Epoch 84/100
# 4800/4800 [==============================] - 28s 6ms/step - loss: 2.9636e-05 - acc: 1.0000 - val_loss: 0.1248 - val_acc: 0.9633
# Epoch 85/100
# 4800/4800 [==============================] - 28s 6ms/step - loss: 2.9481e-05 - acc: 1.0000 - val_loss: 0.1247 - val_acc: 0.9650
# Epoch 86/100
# 4800/4800 [==============================] - 28s 6ms/step - loss: 2.9929e-05 - acc: 1.0000 - val_loss: 0.1249 - val_acc: 0.9642
# Epoch 87/100
# 4800/4800 [==============================] - 28s 6ms/step - loss: 3.9685e-05 - acc: 1.0000 - val_loss: 0.1261 - val_acc: 0.9642
# Epoch 88/100
# 4800/4800 [==============================] - 28s 6ms/step - loss: 2.3159e-05 - acc: 1.0000 - val_loss: 0.1253 - val_acc: 0.9650
# Epoch 89/100
# 4800/4800 [==============================] - 28s 6ms/step - loss: 2.4235e-05 - acc: 1.0000 - val_loss: 0.1253 - val_acc: 0.9650
# Epoch 90/100
# 4800/4800 [==============================] - 28s 6ms/step - loss: 2.1199e-05 - acc: 1.0000 - val_loss: 0.1246 - val_acc: 0.9658
# Epoch 91/100
# 4800/4800 [==============================] - 28s 6ms/step - loss: 1.7289e-05 - acc: 1.0000 - val_loss: 0.1245 - val_acc: 0.9650
# Epoch 92/100
# 4800/4800 [==============================] - 28s 6ms/step - loss: 3.1998e-05 - acc: 1.0000 - val_loss: 0.1252 - val_acc: 0.9633
# Epoch 93/100
# 4800/4800 [==============================] - 28s 6ms/step - loss: 1.5210e-05 - acc: 1.0000 - val_loss: 0.1243 - val_acc: 0.9633
# Epoch 94/100
# 4800/4800 [==============================] - 28s 6ms/step - loss: 1.1177e-05 - acc: 1.0000 - val_loss: 0.1224 - val_acc: 0.9633
# Epoch 95/100
# 4800/4800 [==============================] - 28s 6ms/step - loss: 1.2023e-05 - acc: 1.0000 - val_loss: 0.1219 - val_acc: 0.9642
# Epoch 96/100
# 4800/4800 [==============================] - 28s 6ms/step - loss: 1.1493e-05 - acc: 1.0000 - val_loss: 0.1213 - val_acc: 0.9642
# Epoch 97/100
# 4800/4800 [==============================] - 28s 6ms/step - loss: 1.3045e-05 - acc: 1.0000 - val_loss: 0.1208 - val_acc: 0.9650
# Epoch 98/100
# 4800/4800 [==============================] - 28s 6ms/step - loss: 1.2894e-05 - acc: 1.0000 - val_loss: 0.1204 - val_acc: 0.9642
# Epoch 99/100
# 4800/4800 [==============================] - 28s 6ms/step - loss: 9.5104e-06 - acc: 1.0000 - val_loss: 0.1200 - val_acc: 0.9650
# Epoch 100/100
# 4800/4800 [==============================] - 28s 6ms/step - loss: 9.3828e-06 - acc: 1.0000 - val_loss: 0.1199 - val_acc: 0.9650

# %%
from tensorflow.keras.models import load_model
best_model = load_model('models/DenseNet121.h5')

# %%
evaluate = best_model.evaluate(valid_x, valid_y)
evaluate
# Out:
# 48/48 [==============================] - 4s 90ms/step
# [0.4914226134618123, 0.875]

# %%
#submission = pd.read_csv('data/val.csv')
#submission['digit'] = np.argmax(best_model.predict([x_test, x_letter_test]), axis=1)
#submission.to_csv('data/val(CNN).csv', index=False)
