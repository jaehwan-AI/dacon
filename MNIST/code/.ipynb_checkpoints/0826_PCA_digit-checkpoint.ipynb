# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from sklearn.decomposition import PCA

# %%
train = np.load('data/train.npy', allow_pickle = 'True')
test = np.load('data/test.npy', allow_pickle = 'True')

# %%
train_image = train[:,2:].reshape(-1,28,28).astype(np.int)
train_digit = train[:,0]
train_letter = train[:,1]
train_del_noise = np.where(train_image>=150, train_image, 0)

test_image = test[:,1:].reshape(-1,28,28).astype(np.int)

# %%
def class_pca(data, num):
    lst = []
    for idx in range(len(data)):
        if train_digit[idx] == num:
            lst.append(train_del_noise[idx])
    lst = np.array(lst)
    
    pca = PCA(n_components=5)
    x = lst.reshape(lst.shape[0],-1).copy()
    w = pca.fit_transform(x)
    
    return pca.components_

# %%
def class_pca_mean(data, num):
    lst = []
    for idx in range(len(data)):
        if train_digit[idx] == num:
            lst.append(train_del_noise[idx])
    lst = np.array(lst)
    
    pca = PCA(n_components=5)
    x = lst.reshape(lst.shape[0],-1).copy()
    w = pca.fit_transform(x)
    
    return pca.mean_

# %%
mean_3 = class_pca_mean(train_del_noise, 3)
plt.imshow(mean_3.reshape(28,28))
plt.axis('off')
# Out:
# (-0.5, 27.5, 27.5, -0.5)

# %%
print(np.max(mean_3))
print(np.min(mean_3))
# Out:
# 102.42439024390244
# 0.0

# %%
# image 1
train_1 = []
for idx in range(len(train)):
    if train_digit[idx] == 1:
        train_1.append(train_del_noise[idx])
train_1 = np.array(train_1)

pca = PCA(n_components=5)
x = train_1.reshape(train_1.shape[0],-1).copy()
w = pca.fit_transform(x)
x_ = pca.inverse_transform(w)

fig, axes = plt.subplots(1, 5,
                         subplot_kw={'xticks':(),'yticks':()})

for i, (comp, ax) in enumerate(zip(pca.components_, axes.ravel())):
    ax.imshow(comp.reshape(28,28))
    ax.set_title('PC {}'.format(i+1))
plt.show()

# %%
# image 2
train_2 = []
for idx in range(len(train)):
    if train_digit[idx] == 2:
        train_2.append(train_del_noise[idx])
train_2 = np.array(train_2)

pca = PCA(n_components=5)
x = train_2.reshape(train_2.shape[0],-1).copy()
w = pca.fit_transform(x)
x_ = pca.inverse_transform(w)

fig, axes = plt.subplots(1, 5,
                         subplot_kw={'xticks':(),'yticks':()})

for i, (comp, ax) in enumerate(zip(pca.components_, axes.ravel())):
    ax.imshow(comp.reshape(28,28))
    ax.set_title('PC {}'.format(i+1))
plt.show()

# %%
# image 3
train_3 = []
for idx in range(len(train)):
    if train_digit[idx] == 3:
        train_3.append(train_del_noise[idx])
train_3 = np.array(train_3)

pca = PCA(n_components=5)
x = train_3.reshape(train_3.shape[0],-1).copy()
w = pca.fit_transform(x)
x_ = pca.inverse_transform(w)

fig, axes = plt.subplots(1, 5,
                         subplot_kw={'xticks':(),'yticks':()})

for i, (comp, ax) in enumerate(zip(pca.components_, axes.ravel())):
    ax.imshow(comp.reshape(28,28))
    ax.set_title('PC {}'.format(i+1))
plt.show()

# %%
# image 4
train_4 = []
for idx in range(len(train)):
    if train_digit[idx] == 4:
        train_4.append(train_del_noise[idx])
train_4 = np.array(train_4)

pca = PCA(n_components=5)
x = train_4.reshape(train_4.shape[0],-1).copy()
w = pca.fit_transform(x)
x_ = pca.inverse_transform(w)

fig, axes = plt.subplots(1, 5,
                         subplot_kw={'xticks':(),'yticks':()})

for i, (comp, ax) in enumerate(zip(pca.components_, axes.ravel())):
    ax.imshow(comp.reshape(28,28))
    ax.set_title('PC {}'.format(i+1))
plt.show()

# %%
# image 5
train_5 = []
for idx in range(len(train)):
    if train_digit[idx] == 5:
        train_5.append(train_del_noise[idx])
train_5 = np.array(train_5)

pca = PCA(n_components=5)
x = train_5.reshape(train_5.shape[0],-1).copy()
w = pca.fit_transform(x)
x_ = pca.inverse_transform(w)

fig, axes = plt.subplots(1, 5,
                         subplot_kw={'xticks':(),'yticks':()})

for i, (comp, ax) in enumerate(zip(pca.components_, axes.ravel())):
    ax.imshow(comp.reshape(28,28))
    ax.set_title('PC {}'.format(i+1))
plt.show()

# %%
# image 6
train_6 = []
for idx in range(len(train)):
    if train_digit[idx] == 6:
        train_6.append(train_del_noise[idx])
train_6 = np.array(train_6)

pca = PCA(n_components=5)
x = train_6.reshape(train_6.shape[0],-1).copy()
w = pca.fit_transform(x)
x_ = pca.inverse_transform(w)

fig, axes = plt.subplots(1, 5,
                         subplot_kw={'xticks':(),'yticks':()})

for i, (comp, ax) in enumerate(zip(pca.components_, axes.ravel())):
    ax.imshow(comp.reshape(28,28))
    ax.set_title('PC {}'.format(i+1))
plt.show()

# %%
# image 7
train_7 = []
for idx in range(len(train)):
    if train_digit[idx] == 7:
        train_7.append(train_del_noise[idx])
train_7 = np.array(train_7)

pca = PCA(n_components=5)
x = train_7.reshape(train_7.shape[0],-1).copy()
w = pca.fit_transform(x)
x_ = pca.inverse_transform(w)

fig, axes = plt.subplots(1, 5,
                         subplot_kw={'xticks':(),'yticks':()})

for i, (comp, ax) in enumerate(zip(pca.components_, axes.ravel())):
    ax.imshow(comp.reshape(28,28))
    ax.set_title('PC {}'.format(i+1))
plt.show()

# %%
# image 8
train_8 = []
for idx in range(len(train)):
    if train_digit[idx] == 8:
        train_8.append(train_del_noise[idx])
train_8 = np.array(train_8)

pca = PCA(n_components=5)
x = train_8.reshape(train_8.shape[0],-1).copy()
w = pca.fit_transform(x)
x_ = pca.inverse_transform(w)

fig, axes = plt.subplots(1, 5,
                         subplot_kw={'xticks':(),'yticks':()})

for i, (comp, ax) in enumerate(zip(pca.components_, axes.ravel())):
    ax.imshow(comp.reshape(28,28))
    ax.set_title('PC {}'.format(i+1))
plt.show()

# %%
# image 9
train_9 = []
for idx in range(len(train)):
    if train_digit[idx] == 9:
        train_9.append(train_del_noise[idx])
train_9 = np.array(train_9)

pca = PCA(n_components=5)
x = train_9.reshape(train_9.shape[0],-1).copy()
w = pca.fit_transform(x)
x_ = pca.inverse_transform(w)

fig, axes = plt.subplots(1, 5,
                         subplot_kw={'xticks':(),'yticks':()})

for i, (comp, ax) in enumerate(zip(pca.components_, axes.ravel())):
    ax.imshow(comp.reshape(28,28))
    ax.set_title('PC {}'.format(i+1))
plt.show()

# %%
# image 0
train_0 = []
for idx in range(len(train)):
    if train_digit[idx] == 0:
        train_0.append(train_del_noise[idx])
train_0 = np.array(train_0)

pca = PCA(n_components=5)
x = train_0.reshape(train_0.shape[0],-1).copy()
w = pca.fit_transform(x)
x_ = pca.inverse_transform(w)

fig, axes = plt.subplots(1, 5,
                         subplot_kw={'xticks':(),'yticks':()})

for i, (comp, ax) in enumerate(zip(pca.components_, axes.ravel())):
    ax.imshow(comp.reshape(28,28))
    ax.set_title('PC {}'.format(i+1))
plt.show()
