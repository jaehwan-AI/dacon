# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense
from tensorflow.keras.layers import concatenate, Dropout, GlobalAveragePooling2D
from tensorflow.keras.layers import BatchNormalization, Activation, AveragePooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# seed
import os
seed = 123
os.environ['PYTHONHASHSEED'] = str(seed)
np.random.seed(seed)
tf.set_random_seed(seed)

# %%
train = np.load('data/train.npy', allow_pickle = 'True')
test = np.load('data/test.npy', allow_pickle = 'True')

# %%
x = train[:,2:]
x = np.reshape(x, (-1, 28, 28, 1))

x_letter = train[:,1]
x_letter = np.reshape(x_letter, (-1, 1))
en = OneHotEncoder()
x_letter = en.fit_transform(x_letter).toarray()

y = train[:,0]
y = np.reshape(y, (-1, 1))
en = OneHotEncoder()
y = en.fit_transform(y).toarray()

print(x.shape)
print(x_letter.shape)
print(y.shape)
# Out:
# (2048, 28, 28, 1)
# (2048, 26)
# (2048, 10)

# %%
image_generator = ImageDataGenerator(width_shift_range=0.1,
                                     height_shift_range=0.1, 
                                     zoom_range=[0.8,1.2],
                                     shear_range=10)

# %%
x_total = x.copy()
def augment(x):
    aug_list = []
    for i in range(x.shape[0]):
        num_aug = 0
        tmp = x[i]
        tmp = tmp.reshape((1,) + tmp.shape)
        for x_aug in image_generator.flow(tmp, batch_size = 1) :
            if num_aug >= 1:
                break
            aug_list.append(x_aug[0])
            num_aug += 1
    aug_list = np.array(aug_list)
    return aug_list

n = 2
for i in range(n):
    arr = augment(x)
    x_total = np.concatenate((x_total, arr), axis=0)
    if i > n:
        break

print(x_total.shape)
# Out:
# (6144, 28, 28, 1)

# %%
y_total = y.copy()
for i in range(n):
    arr = y.copy()
    y_total = np.concatenate((y_total, arr), axis=0)

print(y_total.shape)
# Out:
# (6144, 10)

# %%
x_letter_total = x_letter.copy()
for i in range(n):
    arr = x_letter.copy()
    x_letter_total = np.concatenate((x_letter_total, arr), axis=0)
    
print(x_letter_total.shape)
# Out:
# (6144, 26)

# %%
x_train, x_val, y_train, y_val = train_test_split(x_total, y_total, test_size=0.2, shuffle=True)#, stratify=y_total)
x_letter_train = x_letter_total[:x_train.shape[0],:]
x_letter_val = x_letter_total[x_train.shape[0]:,:]

print(x_train.shape)
print(x_val.shape)
print(y_train.shape)
print(y_val.shape)
print(x_letter_train.shape)
print(x_letter_val.shape)
# Out:
# (4915, 28, 28, 1)
# (1229, 28, 28, 1)
# (4915, 10)
# (1229, 10)
# (4915, 26)
# (1229, 26)

# %%
def Conv_block(x, growth_rate, activation='relu'):
    x_l = BatchNormalization()(x)
    x_l = Activation(activation)(x_l)
    x_l = Conv2D(growth_rate*4, (1,1), padding='same', kernel_initializer='he_normal')(x_l)
    
    x_l = BatchNormalization()(x_l)
    x_l = Activation(activation)(x_l)
    x_l = Conv2D(growth_rate, (3,3), padding='same', kernel_initializer='he_normal')(x_l)
    
    x = concatenate([x, x_l])
    return x

def Dense_block(x, layers, growth_rate=32):
    for i in range(layers):
        x = Conv_block(x, growth_rate)
    return x

def Transition_layer(x, compression_factor=0.5, activation='relu'):
    reduced_filters = int(tf.keras.backend.int_shape(x)[-1] * compression_factor)
    
    x = BatchNormalization()(x)
    x = Activation(activation)(x)
    x = Conv2D(reduced_filters, (1,1), padding='same', kernel_initializer='he_normal')(x)
    
    x = AveragePooling2D((2,2), padding='same', strides=2)(x)
    return x

def DenseNet(model_input, classes, densenet_type='DenseNet-121'):
    x = Conv2D(base_growth_rate*2, (5,5), padding='same', strides=1,
               kernel_initializer='he_normal')(model_input)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    
    x = MaxPooling2D((2,2), padding='same', strides=1)(x)
    
    x = Dense_block(x, layers_in_block[densenet_type][0], base_growth_rate)
    x = Transition_layer(x, compression_factor=0.5)
    x = Dense_block(x, layers_in_block[densenet_type][1], base_growth_rate)
    x = Transition_layer(x, compression_factor=0.5)
    x = Dense_block(x, layers_in_block[densenet_type][2], base_growth_rate)
    #x = Transition_layer(x, compression_factor=0.5)
    #x = Dense_block(x, layers_in_block[densenet_type][3], base_growth_rate)
    
    x = GlobalAveragePooling2D()(x)
    
    model_output = Dense(classes, activation='softmax', kernel_initializer='he_normal')(x)
    
    model = Model(model_input, model_output, name=densenet_type)
    
    return model

# %%
layers_in_block = {'DenseNet-121':[6, 12, 24, 16],
                   'DenseNet-169':[6, 12, 32, 32],
                   'DenseNet-201':[6, 12, 48, 32],
                   'DenseNet-265':[6, 12, 64, 48],
                   'myDenseNet':[8, 12, 16, 32]}

base_growth_rate = 32

model_input = Input(shape=(28,28,1))
classes = 10

model = DenseNet(model_input, classes, 'myDenseNet')

model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 28, 28, 1)    0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 28, 28, 64)   1664        input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 28, 28, 64)   256         conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 28, 28, 64)   0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 28, 28, 64)   0           activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 28, 28, 64)   256         max_pooling2d[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 28, 28, 64)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 28, 28, 128)  8320        activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 28, 28, 128)  512         conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 28, 28, 128)  0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 28, 28, 32)   36896       activation_2[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 28, 28, 96)   0           max_pooling2d[0][0]
#                                                                  conv2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 28, 28, 96)   384         concatenate[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 28, 28, 96)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 28, 28, 128)  12416       activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 28, 28, 128)  512         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 28, 28, 128)  0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 28, 28, 32)   36896       activation_4[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 28, 28, 128)  0           concatenate[0][0]
#                                                                  conv2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 28, 28, 128)  512         concatenate_1[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 28, 28, 128)  0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 28, 28, 128)  16512       activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 28, 28, 128)  512         conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 28, 28, 128)  0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 28, 28, 32)   36896       activation_6[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 28, 28, 160)  0           concatenate_1[0][0]
#                                                                  conv2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 28, 28, 160)  640         concatenate_2[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 28, 28, 160)  0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 28, 28, 128)  20608       activation_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 28, 28, 128)  512         conv2d_7[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 28, 28, 128)  0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 28, 28, 32)   36896       activation_8[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 28, 28, 192)  0           concatenate_2[0][0]
#                                                                  conv2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 28, 28, 192)  768         concatenate_3[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 28, 28, 192)  0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 28, 28, 128)  24704       activation_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 28, 28, 128)  512         conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 28, 28, 128)  0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 28, 28, 32)   36896       activation_10[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 28, 28, 224)  0           concatenate_3[0][0]
#                                                                  conv2d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 28, 28, 224)  896         concatenate_4[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 28, 28, 224)  0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 28, 28, 128)  28800       activation_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 28, 28, 128)  512         conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 28, 28, 128)  0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 28, 28, 32)   36896       activation_12[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 28, 28, 256)  0           concatenate_4[0][0]
#                                                                  conv2d_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 28, 28, 256)  1024        concatenate_5[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 28, 28, 256)  0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 28, 28, 128)  32896       activation_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 28, 28, 128)  512         conv2d_13[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 28, 28, 128)  0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 28, 28, 32)   36896       activation_14[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 28, 28, 288)  0           concatenate_5[0][0]
#                                                                  conv2d_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 28, 28, 288)  1152        concatenate_6[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 28, 28, 288)  0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 28, 28, 128)  36992       activation_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 28, 28, 128)  512         conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 28, 28, 128)  0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 28, 28, 32)   36896       activation_16[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 28, 28, 320)  0           concatenate_6[0][0]
#                                                                  conv2d_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 28, 28, 320)  1280        concatenate_7[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 28, 28, 320)  0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 28, 28, 160)  51360       activation_17[0][0]
# __________________________________________________________________________________________________
# average_pooling2d (AveragePooli (None, 14, 14, 160)  0           conv2d_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 14, 14, 160)  640         average_pooling2d[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 14, 14, 160)  0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 14, 14, 128)  20608       activation_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 14, 14, 128)  512         conv2d_18[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 14, 14, 128)  0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 14, 14, 32)   36896       activation_19[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 14, 14, 192)  0           average_pooling2d[0][0]
#                                                                  conv2d_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 14, 14, 192)  768         concatenate_8[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 14, 14, 192)  0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 14, 14, 128)  24704       activation_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 14, 14, 128)  512         conv2d_20[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 14, 14, 128)  0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 14, 14, 32)   36896       activation_21[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 14, 14, 224)  0           concatenate_8[0][0]
#                                                                  conv2d_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 14, 14, 224)  896         concatenate_9[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 14, 14, 224)  0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 14, 14, 128)  28800       activation_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 14, 14, 128)  512         conv2d_22[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 14, 14, 128)  0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 14, 14, 32)   36896       activation_23[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 14, 14, 256)  0           concatenate_9[0][0]
#                                                                  conv2d_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 14, 14, 256)  1024        concatenate_10[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 14, 14, 256)  0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 14, 14, 128)  32896       activation_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 14, 14, 128)  512         conv2d_24[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 14, 14, 128)  0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 14, 14, 32)   36896       activation_25[0][0]
# __________________________________________________________________________________________________
# concatenate_11 (Concatenate)    (None, 14, 14, 288)  0           concatenate_10[0][0]
#                                                                  conv2d_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 14, 14, 288)  1152        concatenate_11[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 14, 14, 288)  0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 14, 14, 128)  36992       activation_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 14, 14, 128)  512         conv2d_26[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 14, 14, 128)  0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 14, 14, 32)   36896       activation_27[0][0]
# __________________________________________________________________________________________________
# concatenate_12 (Concatenate)    (None, 14, 14, 320)  0           concatenate_11[0][0]
#                                                                  conv2d_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 14, 14, 320)  1280        concatenate_12[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 14, 14, 320)  0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 14, 14, 128)  41088       activation_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 14, 14, 128)  512         conv2d_28[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 14, 14, 128)  0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 14, 14, 32)   36896       activation_29[0][0]
# __________________________________________________________________________________________________
# concatenate_13 (Concatenate)    (None, 14, 14, 352)  0           concatenate_12[0][0]
#                                                                  conv2d_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 14, 14, 352)  1408        concatenate_13[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 14, 14, 352)  0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 14, 14, 128)  45184       activation_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 14, 14, 128)  512         conv2d_30[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 14, 14, 128)  0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 14, 14, 32)   36896       activation_31[0][0]
# __________________________________________________________________________________________________
# concatenate_14 (Concatenate)    (None, 14, 14, 384)  0           concatenate_13[0][0]
#                                                                  conv2d_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 14, 14, 384)  1536        concatenate_14[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 14, 14, 384)  0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 14, 14, 128)  49280       activation_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 14, 14, 128)  512         conv2d_32[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 14, 14, 128)  0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 14, 14, 32)   36896       activation_33[0][0]
# __________________________________________________________________________________________________
# concatenate_15 (Concatenate)    (None, 14, 14, 416)  0           concatenate_14[0][0]
#                                                                  conv2d_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 14, 14, 416)  1664        concatenate_15[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 14, 14, 416)  0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 14, 14, 128)  53376       activation_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 14, 14, 128)  512         conv2d_34[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 14, 14, 128)  0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 14, 14, 32)   36896       activation_35[0][0]
# __________________________________________________________________________________________________
# concatenate_16 (Concatenate)    (None, 14, 14, 448)  0           concatenate_15[0][0]
#                                                                  conv2d_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 14, 14, 448)  1792        concatenate_16[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 14, 14, 448)  0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 14, 14, 128)  57472       activation_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 14, 14, 128)  512         conv2d_36[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 14, 14, 128)  0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 14, 14, 32)   36896       activation_37[0][0]
# __________________________________________________________________________________________________
# concatenate_17 (Concatenate)    (None, 14, 14, 480)  0           concatenate_16[0][0]
#                                                                  conv2d_37[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 14, 14, 480)  1920        concatenate_17[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 14, 14, 480)  0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 14, 14, 128)  61568       activation_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 14, 14, 128)  512         conv2d_38[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 14, 14, 128)  0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 14, 14, 32)   36896       activation_39[0][0]
# __________________________________________________________________________________________________
# concatenate_18 (Concatenate)    (None, 14, 14, 512)  0           concatenate_17[0][0]
#                                                                  conv2d_39[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 14, 14, 512)  2048        concatenate_18[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 14, 14, 512)  0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 14, 14, 128)  65664       activation_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 14, 14, 128)  512         conv2d_40[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 14, 14, 128)  0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 14, 14, 32)   36896       activation_41[0][0]
# __________________________________________________________________________________________________
# concatenate_19 (Concatenate)    (None, 14, 14, 544)  0           concatenate_18[0][0]
#                                                                  conv2d_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 14, 14, 544)  2176        concatenate_19[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 14, 14, 544)  0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 14, 14, 272)  148240      activation_42[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 7, 7, 272)    0           conv2d_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 7, 7, 272)    1088        average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 7, 7, 272)    0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 7, 7, 128)    34944       activation_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 7, 7, 128)    512         conv2d_43[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 7, 7, 128)    0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 7, 7, 32)     36896       activation_44[0][0]
# __________________________________________________________________________________________________
# concatenate_20 (Concatenate)    (None, 7, 7, 304)    0           average_pooling2d_1[0][0]
#                                                                  conv2d_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 7, 7, 304)    1216        concatenate_20[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 7, 7, 304)    0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 7, 7, 128)    39040       activation_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 7, 7, 128)    512         conv2d_45[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 7, 7, 128)    0           batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 7, 7, 32)     36896       activation_46[0][0]
# __________________________________________________________________________________________________
# concatenate_21 (Concatenate)    (None, 7, 7, 336)    0           concatenate_20[0][0]
#                                                                  conv2d_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 7, 7, 336)    1344        concatenate_21[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 7, 7, 336)    0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 7, 7, 128)    43136       activation_47[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 7, 7, 128)    512         conv2d_47[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 7, 7, 128)    0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 7, 7, 32)     36896       activation_48[0][0]
# __________________________________________________________________________________________________
# concatenate_22 (Concatenate)    (None, 7, 7, 368)    0           concatenate_21[0][0]
#                                                                  conv2d_48[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 7, 7, 368)    1472        concatenate_22[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 7, 7, 368)    0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 7, 7, 128)    47232       activation_49[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 7, 7, 128)    512         conv2d_49[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, 7, 7, 128)    0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 7, 7, 32)     36896       activation_50[0][0]
# __________________________________________________________________________________________________
# concatenate_23 (Concatenate)    (None, 7, 7, 400)    0           concatenate_22[0][0]
#                                                                  conv2d_50[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 7, 7, 400)    1600        concatenate_23[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, 7, 7, 400)    0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 7, 7, 128)    51328       activation_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 7, 7, 128)    512         conv2d_51[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, 7, 7, 128)    0           batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 7, 7, 32)     36896       activation_52[0][0]
# __________________________________________________________________________________________________
# concatenate_24 (Concatenate)    (None, 7, 7, 432)    0           concatenate_23[0][0]
#                                                                  conv2d_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 7, 7, 432)    1728        concatenate_24[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, 7, 7, 432)    0           batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 7, 7, 128)    55424       activation_53[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, 7, 7, 128)    512         conv2d_53[0][0]
# __________________________________________________________________________________________________
# activation_54 (Activation)      (None, 7, 7, 128)    0           batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 7, 7, 32)     36896       activation_54[0][0]
# __________________________________________________________________________________________________
# concatenate_25 (Concatenate)    (None, 7, 7, 464)    0           concatenate_24[0][0]
#                                                                  conv2d_54[0][0]
# __________________________________________________________________________________________________
# batch_normalization_55 (BatchNo (None, 7, 7, 464)    1856        concatenate_25[0][0]
# __________________________________________________________________________________________________
# activation_55 (Activation)      (None, 7, 7, 464)    0           batch_normalization_55[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 7, 7, 128)    59520       activation_55[0][0]
# __________________________________________________________________________________________________
# batch_normalization_56 (BatchNo (None, 7, 7, 128)    512         conv2d_55[0][0]
# __________________________________________________________________________________________________
# activation_56 (Activation)      (None, 7, 7, 128)    0           batch_normalization_56[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 7, 7, 32)     36896       activation_56[0][0]
# __________________________________________________________________________________________________
# concatenate_26 (Concatenate)    (None, 7, 7, 496)    0           concatenate_25[0][0]
#                                                                  conv2d_56[0][0]
# __________________________________________________________________________________________________
# batch_normalization_57 (BatchNo (None, 7, 7, 496)    1984        concatenate_26[0][0]
# __________________________________________________________________________________________________
# activation_57 (Activation)      (None, 7, 7, 496)    0           batch_normalization_57[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 7, 7, 128)    63616       activation_57[0][0]
# __________________________________________________________________________________________________
# batch_normalization_58 (BatchNo (None, 7, 7, 128)    512         conv2d_57[0][0]
# __________________________________________________________________________________________________
# activation_58 (Activation)      (None, 7, 7, 128)    0           batch_normalization_58[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 7, 7, 32)     36896       activation_58[0][0]
# __________________________________________________________________________________________________
# concatenate_27 (Concatenate)    (None, 7, 7, 528)    0           concatenate_26[0][0]
#                                                                  conv2d_58[0][0]
# __________________________________________________________________________________________________
# batch_normalization_59 (BatchNo (None, 7, 7, 528)    2112        concatenate_27[0][0]
# __________________________________________________________________________________________________
# activation_59 (Activation)      (None, 7, 7, 528)    0           batch_normalization_59[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, 7, 7, 128)    67712       activation_59[0][0]
# __________________________________________________________________________________________________
# batch_normalization_60 (BatchNo (None, 7, 7, 128)    512         conv2d_59[0][0]
# __________________________________________________________________________________________________
# activation_60 (Activation)      (None, 7, 7, 128)    0           batch_normalization_60[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, 7, 7, 32)     36896       activation_60[0][0]
# __________________________________________________________________________________________________
# concatenate_28 (Concatenate)    (None, 7, 7, 560)    0           concatenate_27[0][0]
#                                                                  conv2d_60[0][0]
# __________________________________________________________________________________________________
# batch_normalization_61 (BatchNo (None, 7, 7, 560)    2240        concatenate_28[0][0]
# __________________________________________________________________________________________________
# activation_61 (Activation)      (None, 7, 7, 560)    0           batch_normalization_61[0][0]
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, 7, 7, 128)    71808       activation_61[0][0]
# __________________________________________________________________________________________________
# batch_normalization_62 (BatchNo (None, 7, 7, 128)    512         conv2d_61[0][0]
# __________________________________________________________________________________________________
# activation_62 (Activation)      (None, 7, 7, 128)    0           batch_normalization_62[0][0]
# __________________________________________________________________________________________________
# conv2d_62 (Conv2D)              (None, 7, 7, 32)     36896       activation_62[0][0]
# __________________________________________________________________________________________________
# concatenate_29 (Concatenate)    (None, 7, 7, 592)    0           concatenate_28[0][0]
#                                                                  conv2d_62[0][0]
# __________________________________________________________________________________________________
# batch_normalization_63 (BatchNo (None, 7, 7, 592)    2368        concatenate_29[0][0]
# __________________________________________________________________________________________________
# activation_63 (Activation)      (None, 7, 7, 592)    0           batch_normalization_63[0][0]
# __________________________________________________________________________________________________
# conv2d_63 (Conv2D)              (None, 7, 7, 128)    75904       activation_63[0][0]
# __________________________________________________________________________________________________
# batch_normalization_64 (BatchNo (None, 7, 7, 128)    512         conv2d_63[0][0]
# __________________________________________________________________________________________________
# activation_64 (Activation)      (None, 7, 7, 128)    0           batch_normalization_64[0][0]
# __________________________________________________________________________________________________
# conv2d_64 (Conv2D)              (None, 7, 7, 32)     36896       activation_64[0][0]
# __________________________________________________________________________________________________
# concatenate_30 (Concatenate)    (None, 7, 7, 624)    0           concatenate_29[0][0]
#                                                                  conv2d_64[0][0]
# __________________________________________________________________________________________________
# batch_normalization_65 (BatchNo (None, 7, 7, 624)    2496        concatenate_30[0][0]
# __________________________________________________________________________________________________
# activation_65 (Activation)      (None, 7, 7, 624)    0           batch_normalization_65[0][0]
# __________________________________________________________________________________________________
# conv2d_65 (Conv2D)              (None, 7, 7, 128)    80000       activation_65[0][0]
# __________________________________________________________________________________________________
# batch_normalization_66 (BatchNo (None, 7, 7, 128)    512         conv2d_65[0][0]
# __________________________________________________________________________________________________
# activation_66 (Activation)      (None, 7, 7, 128)    0           batch_normalization_66[0][0]
# __________________________________________________________________________________________________
# conv2d_66 (Conv2D)              (None, 7, 7, 32)     36896       activation_66[0][0]
# __________________________________________________________________________________________________
# concatenate_31 (Concatenate)    (None, 7, 7, 656)    0           concatenate_30[0][0]
#                                                                  conv2d_66[0][0]
# __________________________________________________________________________________________________
# batch_normalization_67 (BatchNo (None, 7, 7, 656)    2624        concatenate_31[0][0]
# __________________________________________________________________________________________________
# activation_67 (Activation)      (None, 7, 7, 656)    0           batch_normalization_67[0][0]
# __________________________________________________________________________________________________
# conv2d_67 (Conv2D)              (None, 7, 7, 128)    84096       activation_67[0][0]
# __________________________________________________________________________________________________
# batch_normalization_68 (BatchNo (None, 7, 7, 128)    512         conv2d_67[0][0]
# __________________________________________________________________________________________________
# activation_68 (Activation)      (None, 7, 7, 128)    0           batch_normalization_68[0][0]
# __________________________________________________________________________________________________
# conv2d_68 (Conv2D)              (None, 7, 7, 32)     36896       activation_68[0][0]
# __________________________________________________________________________________________________
# concatenate_32 (Concatenate)    (None, 7, 7, 688)    0           concatenate_31[0][0]
#                                                                  conv2d_68[0][0]
# __________________________________________________________________________________________________
# batch_normalization_69 (BatchNo (None, 7, 7, 688)    2752        concatenate_32[0][0]
# __________________________________________________________________________________________________
# activation_69 (Activation)      (None, 7, 7, 688)    0           batch_normalization_69[0][0]
# __________________________________________________________________________________________________
# conv2d_69 (Conv2D)              (None, 7, 7, 128)    88192       activation_69[0][0]
# __________________________________________________________________________________________________
# batch_normalization_70 (BatchNo (None, 7, 7, 128)    512         conv2d_69[0][0]
# __________________________________________________________________________________________________
# activation_70 (Activation)      (None, 7, 7, 128)    0           batch_normalization_70[0][0]
# __________________________________________________________________________________________________
# conv2d_70 (Conv2D)              (None, 7, 7, 32)     36896       activation_70[0][0]
# __________________________________________________________________________________________________
# concatenate_33 (Concatenate)    (None, 7, 7, 720)    0           concatenate_32[0][0]
#                                                                  conv2d_70[0][0]
# __________________________________________________________________________________________________
# batch_normalization_71 (BatchNo (None, 7, 7, 720)    2880        concatenate_33[0][0]
# __________________________________________________________________________________________________
# activation_71 (Activation)      (None, 7, 7, 720)    0           batch_normalization_71[0][0]
# __________________________________________________________________________________________________
# conv2d_71 (Conv2D)              (None, 7, 7, 128)    92288       activation_71[0][0]
# __________________________________________________________________________________________________
# batch_normalization_72 (BatchNo (None, 7, 7, 128)    512         conv2d_71[0][0]
# __________________________________________________________________________________________________
# activation_72 (Activation)      (None, 7, 7, 128)    0           batch_normalization_72[0][0]
# __________________________________________________________________________________________________
# conv2d_72 (Conv2D)              (None, 7, 7, 32)     36896       activation_72[0][0]
# __________________________________________________________________________________________________
# concatenate_34 (Concatenate)    (None, 7, 7, 752)    0           concatenate_33[0][0]
#                                                                  conv2d_72[0][0]
# __________________________________________________________________________________________________
# batch_normalization_73 (BatchNo (None, 7, 7, 752)    3008        concatenate_34[0][0]
# __________________________________________________________________________________________________
# activation_73 (Activation)      (None, 7, 7, 752)    0           batch_normalization_73[0][0]
# __________________________________________________________________________________________________
# conv2d_73 (Conv2D)              (None, 7, 7, 128)    96384       activation_73[0][0]
# __________________________________________________________________________________________________
# batch_normalization_74 (BatchNo (None, 7, 7, 128)    512         conv2d_73[0][0]
# __________________________________________________________________________________________________
# activation_74 (Activation)      (None, 7, 7, 128)    0           batch_normalization_74[0][0]
# __________________________________________________________________________________________________
# conv2d_74 (Conv2D)              (None, 7, 7, 32)     36896       activation_74[0][0]
# __________________________________________________________________________________________________
# concatenate_35 (Concatenate)    (None, 7, 7, 784)    0           concatenate_34[0][0]
#                                                                  conv2d_74[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 784)          0           concatenate_35[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 10)           7850        global_average_pooling2d[0][0]
# ==================================================================================================
# Total params: 3,363,546
# Trainable params: 3,325,210
# Non-trainable params: 38,336
# __________________________________________________________________________________________________

# %%
model.compile(optimizer = 'adam', metrics = ['accuracy'], loss = 'categorical_crossentropy')

#es = EarlyStopping(monitor='val_loss', patience=20, mode='min', verbose=1)
cp = ModelCheckpoint('./models/{epoch:02d}-{val_acc:.4f}.h5', monitor='val_loss',
                     save_best_only=True, mode='min')

history = model.fit(x_train, y_train,
                    validation_data=(x_val, y_val), 
                    batch_size=64, epochs=100, verbose=1, callbacks = [cp])
# Out:
# Train on 4915 samples, validate on 1229 samples
# Epoch 1/100
# 4915/4915 [==============================] - 54s 11ms/step - loss: 1.9892 - acc: 0.3070 - val_loss: 8.6995 - val_acc: 0.1155
# Epoch 2/100
# 4915/4915 [==============================] - 28s 6ms/step - loss: 1.1622 - acc: 0.6004 - val_loss: 2.7447 - val_acc: 0.3531
# Epoch 3/100
# 4915/4915 [==============================] - 28s 6ms/step - loss: 0.8627 - acc: 0.7076 - val_loss: 1.9554 - val_acc: 0.5378
# Epoch 4/100
# 4915/4915 [==============================] - 28s 6ms/step - loss: 0.6482 - acc: 0.7827 - val_loss: 1.4524 - val_acc: 0.6330
# Epoch 5/100
# 4915/4915 [==============================] - 28s 6ms/step - loss: 0.4976 - acc: 0.8307 - val_loss: 1.2504 - val_acc: 0.6688
# Epoch 6/100
# 4915/4915 [==============================] - 28s 6ms/step - loss: 0.4102 - acc: 0.8564 - val_loss: 1.4170 - val_acc: 0.6640
# Epoch 7/100
# 4915/4915 [==============================] - 28s 6ms/step - loss: 0.3604 - acc: 0.8730 - val_loss: 2.1664 - val_acc: 0.5989
# Epoch 8/100
# 4915/4915 [==============================] - 28s 6ms/step - loss: 0.2792 - acc: 0.9015 - val_loss: 0.7033 - val_acc: 0.7950
# Epoch 9/100
# 4915/4915 [==============================] - 28s 6ms/step - loss: 0.3124 - acc: 0.8950 - val_loss: 0.8959 - val_acc: 0.7852
# Epoch 10/100
# 4915/4915 [==============================] - 28s 6ms/step - loss: 0.1788 - acc: 0.9373 - val_loss: 0.8032 - val_acc: 0.7771
# Epoch 11/100
# 4915/4915 [==============================] - 28s 6ms/step - loss: 0.2099 - acc: 0.9257 - val_loss: 1.0894 - val_acc: 0.7242
# Epoch 12/100
# 4915/4915 [==============================] - 28s 6ms/step - loss: 0.1315 - acc: 0.9552 - val_loss: 0.5349 - val_acc: 0.8470
# Epoch 13/100
# 4915/4915 [==============================] - 28s 6ms/step - loss: 0.1458 - acc: 0.9487 - val_loss: 0.8278 - val_acc: 0.7819
# Epoch 14/100
# 4915/4915 [==============================] - 28s 6ms/step - loss: 0.1244 - acc: 0.9581 - val_loss: 1.1651 - val_acc: 0.7714
# Epoch 15/100
# 4915/4915 [==============================] - 28s 6ms/step - loss: 0.0926 - acc: 0.9705 - val_loss: 0.5610 - val_acc: 0.8454
# Epoch 16/100
# 4915/4915 [==============================] - 28s 6ms/step - loss: 0.0769 - acc: 0.9764 - val_loss: 0.9505 - val_acc: 0.7925
# Epoch 17/100
# 4915/4915 [==============================] - 28s 6ms/step - loss: 0.0696 - acc: 0.9752 - val_loss: 0.6943 - val_acc: 0.8462
# Epoch 18/100
# 4915/4915 [==============================] - 28s 6ms/step - loss: 0.2131 - acc: 0.9337 - val_loss: 1.4723 - val_acc: 0.7323
# Epoch 19/100
# 4915/4915 [==============================] - 28s 6ms/step - loss: 0.0891 - acc: 0.9721 - val_loss: 0.7164 - val_acc: 0.8381
# Epoch 20/100
# 4915/4915 [==============================] - 28s 6ms/step - loss: 0.0736 - acc: 0.9780 - val_loss: 0.5361 - val_acc: 0.8723
# Epoch 21/100
# 4915/4915 [==============================] - 28s 6ms/step - loss: 0.0472 - acc: 0.9833 - val_loss: 1.3115 - val_acc: 0.7616
# Epoch 22/100
# 4915/4915 [==============================] - 28s 6ms/step - loss: 0.1633 - acc: 0.9499 - val_loss: 0.9787 - val_acc: 0.7893
# Epoch 23/100
# 4915/4915 [==============================] - 28s 6ms/step - loss: 0.0936 - acc: 0.9660 - val_loss: 1.7395 - val_acc: 0.7128
# Epoch 24/100
# 4915/4915 [==============================] - 28s 6ms/step - loss: 0.0709 - acc: 0.9756 - val_loss: 0.8772 - val_acc: 0.8169
# Epoch 25/100
# 4915/4915 [==============================] - 28s 6ms/step - loss: 0.0493 - acc: 0.9811 - val_loss: 0.5531 - val_acc: 0.8682
# Epoch 26/100
# 4915/4915 [==============================] - 28s 6ms/step - loss: 0.0675 - acc: 0.9790 - val_loss: 1.1556 - val_acc: 0.7689
# Epoch 27/100
# 4915/4915 [==============================] - 28s 6ms/step - loss: 0.0595 - acc: 0.9799 - val_loss: 0.6330 - val_acc: 0.8413
# Epoch 28/100
# 4915/4915 [==============================] - 28s 6ms/step - loss: 0.0457 - acc: 0.9839 - val_loss: 1.2152 - val_acc: 0.7746
# Epoch 29/100
# 4915/4915 [==============================] - 28s 6ms/step - loss: 0.0430 - acc: 0.9864 - val_loss: 1.0704 - val_acc: 0.8145
# Epoch 30/100
# 4915/4915 [==============================] - 27s 6ms/step - loss: 0.0722 - acc: 0.9754 - val_loss: 1.4401 - val_acc: 0.7640
# Epoch 31/100
# 4915/4915 [==============================] - 28s 6ms/step - loss: 0.0901 - acc: 0.9689 - val_loss: 1.4074 - val_acc: 0.7437
# Epoch 32/100
# 4915/4915 [==============================] - 28s 6ms/step - loss: 0.0918 - acc: 0.9723 - val_loss: 0.5361 - val_acc: 0.8755
# Epoch 33/100
# 4915/4915 [==============================] - 28s 6ms/step - loss: 0.0642 - acc: 0.9776 - val_loss: 1.2239 - val_acc: 0.7884
# Epoch 34/100
# 4915/4915 [==============================] - 28s 6ms/step - loss: 0.0454 - acc: 0.9856 - val_loss: 1.0204 - val_acc: 0.8088
# Epoch 35/100
# 4915/4915 [==============================] - 28s 6ms/step - loss: 0.0303 - acc: 0.9898 - val_loss: 0.5360 - val_acc: 0.8771
# Epoch 36/100
# 4915/4915 [==============================] - 28s 6ms/step - loss: 0.0400 - acc: 0.9890 - val_loss: 0.5874 - val_acc: 0.8698
# Epoch 37/100
# 4915/4915 [==============================] - 28s 6ms/step - loss: 0.0761 - acc: 0.9764 - val_loss: 1.5277 - val_acc: 0.7535
# Epoch 38/100
# 4915/4915 [==============================] - 28s 6ms/step - loss: 0.0695 - acc: 0.9774 - val_loss: 0.8808 - val_acc: 0.8234
# Epoch 39/100
# 4915/4915 [==============================] - 28s 6ms/step - loss: 0.0353 - acc: 0.9886 - val_loss: 0.5721 - val_acc: 0.8633
# Epoch 40/100
# 4915/4915 [==============================] - 28s 6ms/step - loss: 0.0234 - acc: 0.9929 - val_loss: 0.4300 - val_acc: 0.8893
# Epoch 41/100
# 4915/4915 [==============================] - 28s 6ms/step - loss: 0.0356 - acc: 0.9898 - val_loss: 1.7683 - val_acc: 0.7136
# Epoch 42/100
# 4915/4915 [==============================] - 28s 6ms/step - loss: 0.0586 - acc: 0.9813 - val_loss: 1.3481 - val_acc: 0.8007
# Epoch 43/100
# 4915/4915 [==============================] - 28s 6ms/step - loss: 0.0262 - acc: 0.9908 - val_loss: 0.4122 - val_acc: 0.9072
# Epoch 44/100
# 4915/4915 [==============================] - 28s 6ms/step - loss: 0.0218 - acc: 0.9923 - val_loss: 0.5378 - val_acc: 0.8975
# Epoch 45/100
# 4915/4915 [==============================] - 28s 6ms/step - loss: 0.0426 - acc: 0.9858 - val_loss: 0.5753 - val_acc: 0.8788
# Epoch 46/100
# 4915/4915 [==============================] - 28s 6ms/step - loss: 0.0320 - acc: 0.9894 - val_loss: 1.2168 - val_acc: 0.7933
# Epoch 47/100
# 4915/4915 [==============================] - 28s 6ms/step - loss: 0.0771 - acc: 0.9752 - val_loss: 1.2333 - val_acc: 0.7925
# Epoch 48/100
# 4915/4915 [==============================] - 28s 6ms/step - loss: 0.0910 - acc: 0.9736 - val_loss: 1.6120 - val_acc: 0.7510
# Epoch 49/100
# 4915/4915 [==============================] - 28s 6ms/step - loss: 0.0350 - acc: 0.9874 - val_loss: 0.7654 - val_acc: 0.8470
# Epoch 50/100
# 4915/4915 [==============================] - 28s 6ms/step - loss: 0.0220 - acc: 0.9935 - val_loss: 0.3186 - val_acc: 0.9186
# Epoch 51/100
# 4915/4915 [==============================] - 28s 6ms/step - loss: 0.0077 - acc: 0.9972 - val_loss: 0.2379 - val_acc: 0.9349
# Epoch 52/100
# 4915/4915 [==============================] - 28s 6ms/step - loss: 0.0031 - acc: 0.9992 - val_loss: 0.2568 - val_acc: 0.9382
# Epoch 53/100
# 4915/4915 [==============================] - 28s 6ms/step - loss: 0.0037 - acc: 0.9986 - val_loss: 0.2480 - val_acc: 0.9300
# Epoch 54/100
# 4915/4915 [==============================] - 28s 6ms/step - loss: 0.0122 - acc: 0.9949 - val_loss: 0.2830 - val_acc: 0.9300
# Epoch 55/100
# 4915/4915 [==============================] - 28s 6ms/step - loss: 0.0462 - acc: 0.9876 - val_loss: 1.1350 - val_acc: 0.8242
# Epoch 56/100
# 4915/4915 [==============================] - 28s 6ms/step - loss: 0.1659 - acc: 0.9526 - val_loss: 2.4038 - val_acc: 0.6721
# Epoch 57/100
# 4915/4915 [==============================] - 28s 6ms/step - loss: 0.1105 - acc: 0.9666 - val_loss: 1.3830 - val_acc: 0.7990
# Epoch 58/100
# 4915/4915 [==============================] - 28s 6ms/step - loss: 0.0730 - acc: 0.9776 - val_loss: 0.6600 - val_acc: 0.8576
# Epoch 59/100
# 4915/4915 [==============================] - 28s 6ms/step - loss: 0.0087 - acc: 0.9959 - val_loss: 0.3689 - val_acc: 0.9146
# Epoch 60/100
# 4915/4915 [==============================] - 28s 6ms/step - loss: 0.0066 - acc: 0.9982 - val_loss: 0.3212 - val_acc: 0.9186
# Epoch 61/100
# 4915/4915 [==============================] - 28s 6ms/step - loss: 0.0223 - acc: 0.9923 - val_loss: 0.8910 - val_acc: 0.8421
# Epoch 62/100
# 4915/4915 [==============================] - 28s 6ms/step - loss: 0.0239 - acc: 0.9927 - val_loss: 1.0166 - val_acc: 0.8234
# Epoch 63/100
# 4915/4915 [==============================] - 28s 6ms/step - loss: 0.0385 - acc: 0.9892 - val_loss: 0.3508 - val_acc: 0.9203
# Epoch 64/100
# 4915/4915 [==============================] - 28s 6ms/step - loss: 0.0614 - acc: 0.9841 - val_loss: 1.1972 - val_acc: 0.7852
# Epoch 65/100
# 4915/4915 [==============================] - 28s 6ms/step - loss: 0.0475 - acc: 0.9862 - val_loss: 1.0736 - val_acc: 0.8218
# Epoch 66/100
# 4915/4915 [==============================] - 28s 6ms/step - loss: 0.0434 - acc: 0.9851 - val_loss: 0.4528 - val_acc: 0.9170
# Epoch 67/100
# 4915/4915 [==============================] - 28s 6ms/step - loss: 0.0354 - acc: 0.9884 - val_loss: 1.0643 - val_acc: 0.8234
# Epoch 68/100
# 4915/4915 [==============================] - 28s 6ms/step - loss: 0.0236 - acc: 0.9923 - val_loss: 0.2686 - val_acc: 0.9292
# Epoch 69/100
# 4915/4915 [==============================] - 28s 6ms/step - loss: 0.0305 - acc: 0.9923 - val_loss: 0.7562 - val_acc: 0.8739
# Epoch 70/100
# 4915/4915 [==============================] - 28s 6ms/step - loss: 0.0199 - acc: 0.9915 - val_loss: 0.4709 - val_acc: 0.9048
# Epoch 71/100
# 4915/4915 [==============================] - 28s 6ms/step - loss: 0.0324 - acc: 0.9904 - val_loss: 1.2113 - val_acc: 0.8194
# Epoch 72/100
# 4915/4915 [==============================] - 28s 6ms/step - loss: 0.0588 - acc: 0.9813 - val_loss: 0.7329 - val_acc: 0.8674
# Epoch 73/100
# 4915/4915 [==============================] - 28s 6ms/step - loss: 0.0405 - acc: 0.9882 - val_loss: 0.5196 - val_acc: 0.8975
# Epoch 74/100
# 4915/4915 [==============================] - 28s 6ms/step - loss: 0.0426 - acc: 0.9872 - val_loss: 0.5274 - val_acc: 0.8942
# Epoch 75/100
# 4915/4915 [==============================] - 28s 6ms/step - loss: 0.0134 - acc: 0.9963 - val_loss: 0.2770 - val_acc: 0.9382
# Epoch 76/100
# 4915/4915 [==============================] - 28s 6ms/step - loss: 0.0182 - acc: 0.9937 - val_loss: 0.5687 - val_acc: 0.8877
# Epoch 77/100
# 4915/4915 [==============================] - 28s 6ms/step - loss: 0.0240 - acc: 0.9917 - val_loss: 0.3169 - val_acc: 0.9211
# Epoch 78/100
# 4915/4915 [==============================] - 28s 6ms/step - loss: 0.0339 - acc: 0.9904 - val_loss: 1.0807 - val_acc: 0.8324
# Epoch 79/100
# 4915/4915 [==============================] - 28s 6ms/step - loss: 0.0421 - acc: 0.9886 - val_loss: 0.6998 - val_acc: 0.8869
# Epoch 80/100
# 4915/4915 [==============================] - 28s 6ms/step - loss: 0.0189 - acc: 0.9947 - val_loss: 0.8440 - val_acc: 0.8438
# Epoch 81/100
# 4915/4915 [==============================] - 28s 6ms/step - loss: 0.0245 - acc: 0.9915 - val_loss: 0.6388 - val_acc: 0.8820
# Epoch 82/100
# 4915/4915 [==============================] - 28s 6ms/step - loss: 0.0175 - acc: 0.9943 - val_loss: 0.4582 - val_acc: 0.9072
# Epoch 83/100
# 4915/4915 [==============================] - 28s 6ms/step - loss: 0.0290 - acc: 0.9904 - val_loss: 1.0329 - val_acc: 0.8584
# Epoch 84/100
# 4915/4915 [==============================] - 28s 6ms/step - loss: 0.0556 - acc: 0.9862 - val_loss: 0.7965 - val_acc: 0.8698
# Epoch 85/100
# 4915/4915 [==============================] - 28s 6ms/step - loss: 0.0390 - acc: 0.9896 - val_loss: 0.6829 - val_acc: 0.8804
# Epoch 86/100
# 4915/4915 [==============================] - 28s 6ms/step - loss: 0.0247 - acc: 0.9929 - val_loss: 0.4601 - val_acc: 0.9072
# Epoch 87/100
# 4915/4915 [==============================] - 28s 6ms/step - loss: 0.0384 - acc: 0.9902 - val_loss: 0.9874 - val_acc: 0.8316
# Epoch 88/100
# 4915/4915 [==============================] - 28s 6ms/step - loss: 0.0397 - acc: 0.9860 - val_loss: 0.7654 - val_acc: 0.8771
# Epoch 89/100
# 4915/4915 [==============================] - 28s 6ms/step - loss: 0.0356 - acc: 0.9898 - val_loss: 0.3309 - val_acc: 0.9430
# Epoch 90/100
# 4915/4915 [==============================] - 28s 6ms/step - loss: 0.0306 - acc: 0.9904 - val_loss: 1.1111 - val_acc: 0.8259
# Epoch 91/100
# 4915/4915 [==============================] - 28s 6ms/step - loss: 0.0462 - acc: 0.9868 - val_loss: 0.9785 - val_acc: 0.8348
# Epoch 92/100
# 4915/4915 [==============================] - 28s 6ms/step - loss: 0.0234 - acc: 0.9939 - val_loss: 0.3985 - val_acc: 0.9072
# Epoch 93/100
# 4915/4915 [==============================] - 28s 6ms/step - loss: 0.0146 - acc: 0.9953 - val_loss: 0.4950 - val_acc: 0.9040
# Epoch 94/100
# 4915/4915 [==============================] - 28s 6ms/step - loss: 0.0089 - acc: 0.9967 - val_loss: 0.3406 - val_acc: 0.9292
# Epoch 95/100
# 4915/4915 [==============================] - 28s 6ms/step - loss: 0.0090 - acc: 0.9965 - val_loss: 0.4985 - val_acc: 0.9129
# Epoch 96/100
# 4915/4915 [==============================] - 28s 6ms/step - loss: 0.0171 - acc: 0.9943 - val_loss: 0.6506 - val_acc: 0.8836
# Epoch 97/100
# 4915/4915 [==============================] - 28s 6ms/step - loss: 0.0438 - acc: 0.9882 - val_loss: 1.4253 - val_acc: 0.8023
# Epoch 98/100
# 4915/4915 [==============================] - 28s 6ms/step - loss: 0.0188 - acc: 0.9925 - val_loss: 0.5801 - val_acc: 0.9032
# Epoch 99/100
# 4915/4915 [==============================] - 28s 6ms/step - loss: 0.0661 - acc: 0.9803 - val_loss: 1.5998 - val_acc: 0.7844
# Epoch 100/100
# 4915/4915 [==============================] - 28s 6ms/step - loss: 0.0482 - acc: 0.9849 - val_loss: 0.4290 - val_acc: 0.9129

# %%
from tensorflow.keras.models import load_model
best_model = load_model('models/myDenseNet_submit.h5')

# %%
x_test = test[:,1:]
x_test = np.reshape(x_test, (-1, 28, 28, 1))
print(x_test.shape)
# Out:
# (20480, 28, 28, 1)

# %%
submission = pd.read_csv('data/submission.csv')
submission['digit'] = np.argmax(best_model.predict(x_test), axis=1)
submission.to_csv('data/submission_mydensenet(0822).csv', index=False)
